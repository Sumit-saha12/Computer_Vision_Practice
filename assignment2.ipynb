# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
raw_image = cv2.imread('Temp/assignment-2.jpg')
raw_image_RGB = cv2.cvtColor(raw_image,cv2.COLOR_BGR2RGB)
raw_image_GRAY = cv2.cvtColor(raw_image,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(raw_image_RGB)

# %%
clahe = cv2.createCLAHE(clipLimit=5,tileGridSize=(8,8))
clahe_image = clahe.apply(raw_image_GRAY)

# %%
_, thresh = cv2.threshold(clahe_image, 120, 255, cv2.THRESH_BINARY) 
contours,_ = cv2.findContours(thresh, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

image_filled_contour = np.zeros_like(clahe_image)

# contours_sort = sorted(contours, key=cv2.contourArea, reverse=True)[:15] 

for contour in contours_sort:
    x,y,w,h = cv2.boundingRect(contour)
    cv2.rectangle(raw_image_RGB,(x,y),(x+w,y+h),(255,0,0),10)

# %%
plt.imshow(raw_image_RGB)
